# %% [markdown]
# <a href="https://colab.research.google.com/github/Pix10-code/ASCII-MAKER/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ASCII_MAKER

# %%
# !git clone https://github.com/Pix10-code/ASCII-MAKER.git
# Out:
# Cloning into 'ASCII-MAKER'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 16 (delta 5), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (16/16), done.

# %%
cd ASCII-MAKER/
# Out:
# /content/ASCII-MAKER

# %%
# !pip install -r requirements.txt

# %%
# !python ascii_maker.py
# Out:
# ########################################################################################################################################################################################################
# ########################################################################################################################################################################################################
# ########################################################################################################################################################################################################
# ########################################################################################################################################################################################################
# ...
